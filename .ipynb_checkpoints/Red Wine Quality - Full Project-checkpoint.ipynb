# %% [markdown]
# # Predicting Red Wine Quality
#
# In this project we shall attempt to understand which chemical features of red wine are the most important factors which contribute to the quality of red wine.
#
# The dataset used within this project is the 'Red Wine Quality' dataset uploaded to Kaggle by UCI Machine Learning.
#
# Throughout the duration of the project, we shall focus on the following tasks:
#
# 0. Package and Data Imports
# 1. Exploratory Data Analysis and Visualisation
# 2. Data Preprocessing
# 3. Model Creation and Analysis
#     1. 'Good' vs 'Bad' Wine predictions
#     2. Predicting Quality Ratings
#
# ## 0: Package and Data Imports
#
# Let us first import the data visualisation libraries that will be needed for the next section.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# We shall now import the data into a dataframe called 'df'.

# %%
df = pd.read_csv('winequality-red.csv')

# %% [markdown]
# ## 1: Exploratory Data Analysis and Visualisation
#
# In this section we shall attempt to understand the relationship between our data features and the target variable. We shall first check some basic information regarding the dataframe we have created.

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# We can see that we have a total of 11 features that can be used to predict the value of target variable "quality".

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# We also notice that each feature is in a numerical format and that we have a total of 1599 different wines stored within our dataset.
#
# ### 1.1: Impact of Features on our Target Variable
#
# In this section we shall attempt to understand how each of our features in turn impacts the quality rating of wine.
#
# #### 1.1.1: Fixed Acidity

# %%
df.groupby('quality').mean()['fixed acidity'].plot(kind='bar')
plt.ylabel('Mean Fixed Acidity')
# Out:
# Text(0, 0.5, 'Mean Fixed Acidity')

# %% [markdown]
# The plot above shows the average fixed acidity number for each wine grouped by the quality rating it has been given. We can see that the value of this feature does not significantly change with the quality rating. As a result, we can determine that this features is not a useful predictor of the target variable.
#
# #### 1.1.2: Volatile Acidity

# %%
sns.lmplot(x='volatile acidity',y='quality',data=df)

# %%
df.groupby('quality').mean()['volatile acidity'].plot(kind='bar')
plt.ylabel('Mean Volatile Acidity')
# Out:
# Text(0, 0.5, 'Mean Volatile Acidity')

# %% [markdown]
# From the two plots shown above, we can clearly see a strong negative relationship between the quality of wine and its volatile acidity level. Hence, we can deduce that this feature is a significant factor in the prediction of our target variable.
#
# #### 1.1.3: Citric Acid

# %%
df.groupby('quality').mean()['citric acid'].plot(kind='bar')
plt.ylabel('Mean Citric Acid Level')
# Out:
# Text(0, 0.5, 'Mean Citric Acid Level')

# %% [markdown]
# We can clearly visualise a strong, postive relationship between the citric acid level and the wine's quality. This feature is an important factor in predicting the quality rating.
#
# #### 1.1.4: Residual Sugar

# %%
df.groupby('quality').mean()['residual sugar'].plot(kind='bar')
plt.ylabel('Mean Residual Sugar Level')
# Out:
# Text(0, 0.5, 'Mean Residual Sugar Level')

# %% [markdown]
# The plot above shows no clear linear relationship between the quality of wine and the level of residual sugar contained within it.
#
# #### 1.1.5: Chlorides

# %%
df.groupby('quality').mean()['chlorides'].plot(kind='bar')
plt.ylabel('Mean Chloride Level')
# Out:
# Text(0, 0.5, 'Mean Chloride Level')

# %% [markdown]
# From the above plot, we can determine that, on average, a low chloride level leads to a higher quality of wine. This feature is an important factor when predicting the quality of wine.
#
# #### 1.1.6: Free Sulfur Dioxide

# %%
df.groupby('quality').mean()['free sulfur dioxide'].plot(kind='bar')
plt.ylabel('Mean Free Sulfur Dioxide')
# Out:
# Text(0, 0.5, 'Mean Free Sulfur Dioxide')

# %%
sns.scatterplot(x='free sulfur dioxide',y='quality',data=df)

# %% [markdown]
# It is difficult to determine whether this feature has a significant impact on our target variable. For wines with a quality of above 5, as the level of free sulfur dioxide decreases, the quality of wine increases. However, for wines rated as either a 3 or 4, the reverse of this statement is true.
#
# We shall leave this variable within our dataset as it appears like there is some hidden information within this feature.
#
# #### 1.1.7: Total Sulfur Dioxide

# %%
df.groupby('quality').mean()['total sulfur dioxide'].plot(kind='bar')
plt.ylabel('Mean Total Sulfur Dioxide Level')
# Out:
# Text(0, 0.5, 'Mean Total Sulfur Dioxide Level')

# %% [markdown]
# As with free sulfur dioxide above, it is difficult to determine whether this feature is an important factor. Further investigation on the relatonship between the "free sulfur dioxide" and "total sulfur dioxide" shall be done in section 1.2
#
# #### 1.1.8: Density

# %%
df.groupby('quality').mean()['density'].plot(kind='bar')
plt.ylabel('Mean Density')
plt.ylim(0.99,1)
# Out:
# (0.99, 1.0)

# %% [markdown]
# We can see that, despite a negative relationship shown in the graph, there is no clear relationship between the density of the wine and its quality. The range of densities contained within our dataset is so small that any relationship would be insignificant. As a result, we can assume that there is no relationship between these two variables.
#
# #### 1.1.9: pH

# %%
df.groupby('quality').mean()['pH'].plot(kind='bar')
plt.ylabel('Mean pH Level')
# Out:
# Text(0, 0.5, 'Mean pH Level')

# %% [markdown]
# As with density above, there is no significant relationshio between the pH level of a wine and its quality.
#
# #### 1.1.10: Sulphates

# %%
df.groupby('quality').mean()['sulphates'].plot(kind='bar')
plt.ylabel('Mean Sulphate Level')
# Out:
# Text(0, 0.5, 'Mean Sulphate Level')

# %% [markdown]
# The plot of the mean sulphate level by quality class shows a clear, positive relationship between the two variables. This feature is an important factor in predicting the quality of wine.
#
# #### 1.1.11: Alcohol

# %%
df.groupby('quality').mean()['alcohol'].plot(kind='bar')
plt.ylabel('Mean Alcohol Level')
# Out:
# Text(0, 0.5, 'Mean Alcohol Level')

# %% [markdown]
# Once again, we can see a clear relationship between these variables.
#
# In summary, we have found that there seem to be 5 main factors that influence the quality of wine. These are:
#
#  - Alcohol
#  - Sulphates
#  - Chlorides
#  - Citric Acid
#  - Volatile Acidity
#
# Let us produce a plot of the correlation values of all our features to our target variable to confirm these findings.

# %%
series = pd.Series(df.corr()['quality'])
series.drop('quality').plot(kind='bar')

# %% [markdown]
# We can clearly see that the 5 columns mentioned above seem to have a high correlation value, in absolute terms. However, it also seems that the density and total sulfur dioxide features are also significantly correlated to our target variable.
#
# ### 1.2: Feature Relationships
#
# Now that we have determined which features have an impact on our target variable, we shall now begin to investigate the relationships between our features. We shall do this by producing a correlation heatmap.

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# The heatmap above shows the correlation values between each of the features. We shall now investigate values that have a large absolute value.
#
# #### 1.2.1: Fixed Acidity v Citric Acid

# %%
sns.scatterplot(x='fixed acidity',y='citric acid',hue='quality',data=df)

# %% [markdown]
# The first thing to note is that the level of fixed acidity within a wine is always greater than the level of citric acid. This is because citric acid is one of the types of acid considered in the fixed acidity value. We notice a clear positive relationship between these two features, which is why the value of 0.67 in the correlation matrix appears.
#
# Let us investigate whether the percentage of the citric acid has an effect on the quality of wine.

# %%
df['citric acid percentage'] = df['citric acid'] / (df['citric acid'] + df['fixed acidity'])

# %%
df.groupby('quality').mean()['citric acid percentage'].plot(kind='bar')
plt.ylabel('Mean Citric Acid Percentage')
# Out:
# Text(0, 0.5, 'Mean Citric Acid Percentage')

# %% [markdown]
# We can clearly see that the as the average citric acid percentage of the wine increases, the quality score associated to the wine also increases. This is due to the fact that acids impart the fundamental features of a wines taste. We have found another useful characteristic of our target variable.
#
# #### 1.2.2: Fixed Acidity v Density

# %%
sns.scatterplot(x='fixed acidity',y='density',hue='quality',data=df)

# %% [markdown]
# Once again we can see a clear positive relationship between these two variables.
#
# #### 1.2.3: Fixed Acidity v pH

# %%
sns.scatterplot(x='fixed acidity',y='pH',hue='quality',data=df)

# %% [markdown]
# Here, we see a clear negative relationshio between these variables. This intuitively makes sense, since pH is a direct measure of how acidic or alkaline a substance is. The more acidic the wine is, the lower the pH value is because of the scale that is used when measuring pH levels. A substance with 0pH is extremelty acidic, 7pH is neutral and 13pH is extremely alkaline.
#
# #### 1.2.4: Volatile Acidity v Citric Acid

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='volatile acidity',y='citric acid',hue='quality',data=df)

# %% [markdown]
# The negative relationship between these variables is clear. Volatile acidity is commonly used as a measure of wine spoilage, and manufactures aim to keep the level of volatile acidity negligible. This may be the reason why we see more high quality wines to the top left of the scatter plot above. This is because in this region the citric acid levels are high, which contribute to the taste of the wine, and the volatile acidity levels are low, which reduce the spoilage.
#
# #### 1.2.5: Citric Acid v pH

# %%
sns.scatterplot(x='citric acid',y='pH',hue='quality',data=df)

# %% [markdown]
# The relationship between these two variables is clearly negative for the same reasons as the relationship between fixed acidity and pH.
#
# #### 1.2.6: Residual Sugar v Density

# %%
sns.scatterplot(x='residual sugar',y='density',hue='quality',data=df)

# %% [markdown]
# The positive relationship between these two variables is difficult to be seen since the correlation between them is only 0.37.
#
# #### 1.2.7: Chlorides v Sulphates

# %%
sns.scatterplot(x='chlorides',y='sulphates',hue='quality',data=df)

# %% [markdown]
# We can see a slightly positive linear relationship between these two variables. We notice that the majority of the high quality wines are plotted in the left hand part of this graph. This is due to the negative relationship that chlorides have with the wine quality.
#
# #### 1.2.8: Free Sulfur Dioxide v Total Sulfur Dioxide

# %%
sns.scatterplot(x='free sulfur dioxide',y='total sulfur dioxide',hue='quality',data=df)
plt.plot(range(0,71),range(0,71))

# %% [markdown]
# The first thing to notice is that the level of free sulfur dioxide is always less than or equal to the total sulfir dioxide level, which makes intuitive sense. Let us investigate whether the percentage of free sulfur dixoide impacts the quality of wine.

# %%
df['free sulfur dioxide percentage'] = df['free sulfur dioxide'] / (df['free sulfur dioxide'] + df['total sulfur dioxide'])
df.groupby('quality').mean()['free sulfur dioxide percentage'].plot(kind='bar')
plt.ylabel('Mean Free Sulfur Dioxide Percentage')
# Out:
# Text(0, 0.5, 'Mean Free Sulfur Dioxide Percentage')

# %% [markdown]
# We can see that for each quality rating there is a differet average free sulfur dioxide percentage, but there does not exist a clear relationship between these variables. Let us check this by calculating the correlation between these features.

# %%
df.corr()['quality']
# Out:
# fixed acidity                     0.124052
# volatile acidity                 -0.390558
# citric acid                       0.226373
# residual sugar                    0.013732
# chlorides                        -0.128907
# free sulfur dioxide              -0.050656
# total sulfur dioxide             -0.185100
# density                          -0.174919
# pH                               -0.057731
# sulphates                         0.251397
# alcohol                           0.476166
# quality                           1.000000
# citric acid percentage            0.209804
# free sulfur dioxide percentage    0.196055
# Name: quality, dtype: float64

# %% [markdown]
# Our correlation value has been shown to be equal to approximately 0.2, which suggests that there is enough of a relationship to consider this variable for predicting wine quality.
#
# #### 1.2.9: Alcohol v Density

# %%
sns.scatterplot(x='alcohol',y='density',hue='quality',data=df)

# %% [markdown]
# We can see a clear negative relationship between these two variables.
#
# ## 2: Data Preprocessing
#
# In this section we shall manipulate our dataset for use in the machine learning algorithms that we shall implement in section 3.
#
# From the analysis we perform in section 1, we identified 5 key variables in predicting wine quality. These were alcohol, sulphates, chlorides, citric acid and volatile acidity. We also created two new variables, citric acid percentage and free sulfur dioxide percentage, which we also found to be useful.
#
# We must now remove any variables which we find are not useful or variables that may cause multicolinearity issues. As a result, we shall remove the columns free sulfur dioxide and fixed acidity.

# %%
df = df.drop(['free sulfur dioxide','fixed acidity'],axis=1)

# %%
df.head()
# Out:
#    volatile acidity  citric acid  residual sugar  chlorides  \
# 0              0.70         0.00             1.9      0.076
# 1              0.88         0.00             2.6      0.098
# 2              0.76         0.04             2.3      0.092
# 3              0.28         0.56             1.9      0.075
# 4              0.70         0.00             1.9      0.076
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  quality  \
# 0                  34.0   0.9978  3.51       0.56      9.4        5
# 1                  67.0   0.9968  3.20       0.68      9.8        5
# 2                  54.0   0.9970  3.26       0.65      9.8        5
# 3                  60.0   0.9980  3.16       0.58      9.8        6
# 4                  34.0   0.9978  3.51       0.56      9.4        5
#
#    citric acid percentage  free sulfur dioxide percentage
# 0                0.000000                        0.244444
# 1                0.000000                        0.271739
# 2                0.005102                        0.217391
# 3                0.047619                        0.220779
# 4                0.000000                        0.244444

# %% [markdown]
# Let us now check the distribution of our target class by producing a countplot.

# %%
sns.countplot(x='quality',data=df)

# %% [markdown]
# We can see that we have an extremely unbalanced dataset, which may lead to issues when implementing our algorithms. Let us see how unbalanced the dataset really is.

# %%
df.groupby('quality').count()['pH'] * 100 /len(df)
# Out:
# quality
# 3     0.625391
# 4     3.314572
# 5    42.589118
# 6    39.899937
# 7    12.445278
# 8     1.125704
# Name: pH, dtype: float64

# %% [markdown]
# We see that over 80% of our data points belong to either quality rating 5 or 6. However, if we reclassify our points as "good" if they have a quality rating of at least 6 and "bad" otherwise, then we should achieve a much more balanced dataset. Let us create a new target variable called "new_rating" that contains a 1 if the wine is "good" and a 0 if the wine is "bad".

# %%
df['new_rating'] = df['quality'].apply(lambda x: 1 if x >= 6 else 0)

# %% [markdown]
# Let us check the split that this has produced.

# %%
sns.countplot(x='new_rating',data=df)

# %%
df['new_rating'].value_counts() * 100 / len(df)
# Out:
# 1    53.470919
# 0    46.529081
# Name: new_rating, dtype: float64

# %% [markdown]
# We can now clearly see that we have a much more balanced dataset as a result of the new rating system we have implemented.
#
# We are now able to split our data into training and test sets for use in our machine learning algorithms.

# %%
X = df.drop(['quality','new_rating'],axis=1)
y = df['new_rating']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ## 3: Model Creation and Analysis
#
# In this section we shall create and analyse machine learning models in order to predict the quality of wine.
#
# ### 3.1: "Good" vs "Bad" Predictions
#
# In this section, we shall make use of the "new_rating" feature created above to predict whether a wine is either "good" or "bad". We shall implement a range of machine learning algorithms and attempt to determine which method produces the most accuracy. In this case, we are considering a binary classification problem. Let us begin implementing and analysing the following algorithms:
#
# 1. Logistic Regression (75%)
# 2. Decision Tree (74%)
# 3. Random Forest (80%)
# 4. Support Vector Machines (77%)
# 5. XGBoost (78%)
#
# #### 3.1.1: Logistic Regression
#
# We first need to import the Logistic Regression model from scikit-learn. We will then fit the model using our training data, followed by creating predictions using our testing data.

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression(max_iter=1500)
logmodel.fit(X_train, y_train)
logmodelpreds = logmodel.predict(X_test)

# %% [markdown]
# Let us now produce a confusion matrix and a classification report to determine the accuracy of our model.

# %%
from sklearn.metrics import confusion_matrix, classification_report
print("Confusion Matrix: ")
print(confusion_matrix(y_test,logmodelpreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,logmodelpreds))
# Out:
# Confusion Matrix:
# [[161  71]
#  [ 50 198]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.69      0.73       232
#            1       0.74      0.80      0.77       248
#
#     accuracy                           0.75       480
#    macro avg       0.75      0.75      0.75       480
# weighted avg       0.75      0.75      0.75       480

# %% [markdown]
# Since we are attempt to solve a binary classification problem, the key metric to consider is accuracy. In this case, our logistic regression model achieved 75% when predicting wines from the testing set.
#
# The process we shall undertake for the implementation of each model type will be similar to the process we have just undertaken for our logistic regression model. Let us now work through each model in turn and find out its accuracy.
#
# #### 3.1.2: Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
treepreds = tree.predict(X_test)

print("Confusion Matrix: ")
print(confusion_matrix(y_test,treepreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,treepreds))
# Out:
# Confusion Matrix:
# [[162  70]
#  [ 55 193]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.72       232
#            1       0.73      0.78      0.76       248
#
#     accuracy                           0.74       480
#    macro avg       0.74      0.74      0.74       480
# weighted avg       0.74      0.74      0.74       480

# %% [markdown]
# We can see that the decision tree model implemented achieved 74% accuracy.
#
# #### 3.1.3: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=100)
forest.fit(X_train, y_train)
forestpreds = forest.predict(X_test)

print("Confusion Matrix: ")
print(confusion_matrix(y_test,forestpreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,forestpreds))
# Out:
# Confusion Matrix:
# [[177  55]
#  [ 39 209]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79       232
#            1       0.79      0.84      0.82       248
#
#     accuracy                           0.80       480
#    macro avg       0.81      0.80      0.80       480
# weighted avg       0.81      0.80      0.80       480

# %% [markdown]
# Our random forest classifier achieved 80% accuracy.
#
# #### 3.1.4: Support Vector Machines

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
svcpreds = svc.predict(X_test)

print("Confusion Matrix: ")
print(confusion_matrix(y_test,svcpreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,svcpreds))
# Out:
# Confusion Matrix:
# [[ 61 171]
#  [ 29 219]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.26      0.38       232
#            1       0.56      0.88      0.69       248
#
#     accuracy                           0.58       480
#    macro avg       0.62      0.57      0.53       480
# weighted avg       0.62      0.58      0.54       480

# %% [markdown]
# Our support vector machine classifier only achieved 58% accuracy. However, we can use a grid search to attempt to alter the model parameters and achieve a higher accuracy.

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']} 
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.545, total=   0.2s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.545, total=   0.3s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.540, total=   0.3s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.540, total=   0.2s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.543, total=   0.2s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.625, total=   0.2s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.652, total=   0.2s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.607, total=   0.2s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.612, total=   0.1s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.646, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.625, total=   0.2s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.665, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.585, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.616, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.650, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.612, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.643, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.585, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.629, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.668, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.598, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.638, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.585, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.634, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.646, total=   0.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.665, total=   0.2s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.696, total=   0.2s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.670, total=   0.2s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.688, total=   0.2s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.722, total=   0.2s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.714, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.732, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.652, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.656, total=   0.2s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.677, total=   0.2s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.634, total=   0.2s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.670, total=   0.1s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.598, total=   0.2s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.625, total=   0.1s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.668, total=   0.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.621, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.670, total=   0.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.571, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.625, total=   0.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.682, total=   0.1s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.594, total=   0.1s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.634, total=   0.1s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.585, total=   0.1s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.634, total=   0.2s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.646, total=   0.1s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.643, total=   0.3s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.728, total=   0.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.679, total=   0.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.732, total=   0.3s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.717, total=   0.3s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.746, total=   0.2s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.719, total=   0.2s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.679, total=   0.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.701, total=   0.2s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.753, total=   0.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.701, total=   0.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.732, total=   0.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.670, total=   0.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.696, total=   0.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.744, total=   0.1s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.696, total=   0.1s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.705, total=   0.1s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.629, total=   0.1s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.674, total=   0.1s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.700, total=   0.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.621, total=   0.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.679, total=   0.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.589, total=   0.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.647, total=   0.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.686, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.643, total=   0.3s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.719, total=   0.2s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.701, total=   0.2s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.737, total=   0.2s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.709, total=   0.3s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.723, total=   0.3s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.732, total=   0.3s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.705, total=   0.3s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.679, total=   0.3s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.771, total=   0.4s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.754, total=   0.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.737, total=   0.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.719, total=   0.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.683, total=   0.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.780, total=   0.2s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.754, total=   0.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.768, total=   0.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.737, total=   0.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.714, total=   0.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.744, total=   0.1s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.732, total=   0.1s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.754, total=   0.1s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.705, total=   0.1s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.714, total=   0.1s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.722, total=   0.1s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.643, total=   0.3s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.719, total=   0.3s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.701, total=   0.2s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.737, total=   0.2s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.709, total=   0.3s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.705, total=   0.9s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.750, total=   1.0s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.696, total=   0.9s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.710, total=   1.0s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.749, total=   0.9s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.754, total=   0.8s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.741, total=   1.0s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.719, total=   0.7s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.683, total=   0.9s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.771, total=   0.6s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.746, total=   0.3s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.759, total=   0.3s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.728, total=   0.4s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.737, total=   0.3s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.785, total=   0.3s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.754, total=   0.1s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.759, total=   0.2s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.714, total=   0.1s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.723, total=   0.2s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.744, total=   0.2s
# [Parallel(n_jobs=1)]: Done 125 out of 125 | elapsed:   29.4s finished
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
grid.best_estimator_
gridpreds = grid.predict(X_test)

print("Confusion Matrix: ")
print(confusion_matrix(y_test,gridpreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,gridpreds))
# Out:
# Confusion Matrix:
# [[171  61]
#  [ 49 199]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76       232
#            1       0.77      0.80      0.78       248
#
#     accuracy                           0.77       480
#    macro avg       0.77      0.77      0.77       480
# weighted avg       0.77      0.77      0.77       480

# %% [markdown]
# Despite tuning the parameters, we were only able to achieve a 77% accuracy using Support Vector Machines.
#
# #### 3.1.5: XGBoost

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
xgbpreds = xgb.predict(X_test)

print("Confusion Matrix: ")
print(confusion_matrix(y_test,xgbpreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,xgbpreds))
# Out:
# Confusion Matrix:
# [[175  57]
#  [ 51 197]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       232
#            1       0.78      0.79      0.78       248
#
#     accuracy                           0.78       480
#    macro avg       0.77      0.77      0.77       480
# weighted avg       0.77      0.78      0.77       480

# %% [markdown]
# Our XGBoost model achieved 78% accuracy.
#
# In summary, each of our models achieved at least 70% accuracy. The reason for this relatively low score may be due to the fact that there were lots of cases that were located close to boundary between "good" and "bad", since about 40% of our datapoints belonged to both quality rating 5 or 6. However, our random forest model managed to achieve a much better 80% accuracy.
#
# ### 3.2 Predicting Quality Rating
#
# In this section we shall attempt to solve our original problem of predicting the quality rating of wine given its chemical features. Note that our dataset was extremely unbalanced, which was the major reason for considering the "good" v "bad" problem above. In order to predict exact quality ratings, we will need to balance our dataset. We can do this using a technique known as SMOTE, which will synthetically produce more samples of the under represented classes. Let us apply this method and then check the number of each wine within eavh quality rating.
#
# First, we shall remove the "new_rating" target column since it is no longer needed.

# %%
df = df.drop('new_rating',axis=1)
df.head()
# Out:
#    volatile acidity  citric acid  residual sugar  chlorides  \
# 0              0.70         0.00             1.9      0.076
# 1              0.88         0.00             2.6      0.098
# 2              0.76         0.04             2.3      0.092
# 3              0.28         0.56             1.9      0.075
# 4              0.70         0.00             1.9      0.076
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  quality  \
# 0                  34.0   0.9978  3.51       0.56      9.4        5
# 1                  67.0   0.9968  3.20       0.68      9.8        5
# 2                  54.0   0.9970  3.26       0.65      9.8        5
# 3                  60.0   0.9980  3.16       0.58      9.8        6
# 4                  34.0   0.9978  3.51       0.56      9.4        5
#
#    citric acid percentage  free sulfur dioxide percentage
# 0                0.000000                        0.244444
# 1                0.000000                        0.271739
# 2                0.005102                        0.217391
# 3                0.047619                        0.220779
# 4                0.000000                        0.244444

# %% [markdown]
# Let us reorder the columns of order dataframe so that our target variable shows in the last column.

# %%
df = df[['volatile acidity','citric acid','residual sugar','chlorides','total sulfur dioxide','density','pH','sulphates','alcohol','citric acid percentage','free sulfur dioxide percentage','quality']]
df.head(2)
# Out:
#    volatile acidity  citric acid  residual sugar  chlorides  \
# 0              0.70          0.0             1.9      0.076
# 1              0.88          0.0             2.6      0.098
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  \
# 0                  34.0   0.9978  3.51       0.56      9.4
# 1                  67.0   0.9968  3.20       0.68      9.8
#
#    citric acid percentage  free sulfur dioxide percentage  quality
# 0                     0.0                        0.244444        5
# 1                     0.0                        0.271739        5

# %% [markdown]
# We can now implement the SMOTE technique to oversample our dataset which will result in perfectly balanced classes.

# %%
data = df.values
X = data[:, :-1]
y = data[:, -1]
X_columns = df.columns[:-1]
y_columns = df.columns[-1]

from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_sample(X, y)

X_sampled = pd.DataFrame(X, columns=X_columns)
y_sampled = pd.DataFrame(y, columns=[y_columns])
df = pd.concat([X_sampled,y_sampled],axis=1)

# %% [markdown]
# Let us check that the technique worked and that we have balanced classes.

# %%
sns.countplot(x='quality',data=df)

# %%
df['quality'].value_counts()
# Out:
# 3.0    681
# 8.0    681
# 4.0    681
# 7.0    681
# 6.0    681
# 5.0    681
# Name: quality, dtype: int64

# %% [markdown]
# The plot and series above show that we now posses 681 wines for each quality rating, meaning that we have a perfectly balanced dataset as required. Let us now move on to create training and testing sets for this data.

# %%
X = df.drop('quality',axis=1)
y = df['quality']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %% [markdown]
# Now that we have oversampled and split our data into training and test sets, we are now in a position to begin implementing machine learning models to predict the quality of wine.
#
# #### 3.2.1: Logistic Regression

# %%
logmodel = LogisticRegression(max_iter=5000)
logmodel.fit(X_train, y_train)
logmodelpreds = logmodel.predict(X_test)

print("Confusion Matrix: ")
print(confusion_matrix(y_test,logmodelpreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,logmodelpreds))
# Out:
# Confusion Matrix:
# [[141   7   0   5   0   0]
#  [ 26  78  53  17   4   2]
#  [ 13  19 101  25   6   5]
#  [  8  15  42  63  27  21]
#  [  0  11   7  35  59  78]
#  [  0   0   0   0  26 128]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#          3.0       0.75      0.92      0.83       153
#          4.0       0.60      0.43      0.50       180
#          5.0       0.50      0.60      0.54       169
#          6.0       0.43      0.36      0.39       176
#          7.0       0.48      0.31      0.38       190
#          8.0       0.55      0.83      0.66       154
#
#     accuracy                           0.56      1022
#    macro avg       0.55      0.58      0.55      1022
# weighted avg       0.55      0.56      0.54      1022

# %% [markdown]
# Our logistic regression model achieved 56% accuracy.
#
# #### 3.2.2 Decision Tree

# %%
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
treepreds = tree.predict(X_test)

print("Confusion Matrix: ")
print(confusion_matrix(y_test,treepreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,treepreds))
# Out:
# Confusion Matrix:
# [[146   6   1   0   0   0]
#  [  4 147  19   9   1   0]
#  [  2  23 107  29   7   1]
#  [  1  10  31  96  32   6]
#  [  1   2   9  21 151   6]
#  [  0   0   0   2   7 145]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#          3.0       0.95      0.95      0.95       153
#          4.0       0.78      0.82      0.80       180
#          5.0       0.64      0.63      0.64       169
#          6.0       0.61      0.55      0.58       176
#          7.0       0.76      0.79      0.78       190
#          8.0       0.92      0.94      0.93       154
#
#     accuracy                           0.77      1022
#    macro avg       0.78      0.78      0.78      1022
# weighted avg       0.77      0.77      0.77      1022

# %% [markdown]
# We have managed to significantly improve the accuracy of predictions to 77% by using a decision tree.
#
# #### 3.2.3: Random Forest

# %%
forest = RandomForestClassifier(n_estimators=100)
forest.fit(X_train, y_train)
forestpreds = forest.predict(X_test)

print("Confusion Matrix: ")
print(confusion_matrix(y_test,forestpreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,forestpreds))
# Out:
# Confusion Matrix:
# [[152   1   0   0   0   0]
#  [  1 169   9   1   0   0]
#  [  1  13 127  23   5   0]
#  [  2   7  31 100  34   2]
#  [  0   0   3  12 171   4]
#  [  0   0   0   0   1 153]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#          3.0       0.97      0.99      0.98       153
#          4.0       0.89      0.94      0.91       180
#          5.0       0.75      0.75      0.75       169
#          6.0       0.74      0.57      0.64       176
#          7.0       0.81      0.90      0.85       190
#          8.0       0.96      0.99      0.98       154
#
#     accuracy                           0.85      1022
#    macro avg       0.85      0.86      0.85      1022
# weighted avg       0.85      0.85      0.85      1022

# %% [markdown]
# Our random forest model has performed the best out of the models created so far, achieving 85% accuracy on our test data.
#
# #### 3.2.4: Support Vector Machines

# %%
svc = SVC()
svc.fit(X_train, y_train)
svcpreds = svc.predict(X_test)

print("Confusion Matrix: ")
print(confusion_matrix(y_test,svcpreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,svcpreds))
# Out:
# Confusion Matrix:
# [[110   0   0  43   0   0]
#  [ 60   0  45  70   0   5]
#  [ 22   0  69  70   0   8]
#  [ 24   0  32  94   0  26]
#  [ 35   0  17  75   6  57]
#  [ 14   0   0  42   3  95]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#          3.0       0.42      0.72      0.53       153
#          4.0       0.00      0.00      0.00       180
#          5.0       0.42      0.41      0.42       169
#          6.0       0.24      0.53      0.33       176
#          7.0       0.67      0.03      0.06       190
#          8.0       0.50      0.62      0.55       154
#
#     accuracy                           0.37      1022
#    macro avg       0.37      0.38      0.31      1022
# weighted avg       0.37      0.37      0.30      1022
# C:\Users\Joe\anaconda3\envs\test\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Our support vector machine achieves only 37% accuracy. Let us use a grid search to attempt to improve this accuracy.

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']} 
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)
grid.fit(X_train,y_train)

grid.best_estimator_
gridpreds = grid.predict(X_test)

print("Confusion Matrix: ")
print(confusion_matrix(y_test,gridpreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,gridpreds))
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.475, total=   2.2s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.476, total=   1.9s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.0s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.486, total=   1.9s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.427, total=   2.1s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.420, total=   1.9s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.496, total=   1.3s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.494, total=   1.3s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.512, total=   1.3s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.501, total=   1.3s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.464, total=   1.3s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.359, total=   1.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.359, total=   1.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.392, total=   1.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.339, total=   1.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.355, total=   1.1s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.274, total=   1.2s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.268, total=   1.2s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.272, total=   1.2s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.285, total=   1.1s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.275, total=   1.2s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.220, total=   1.2s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.237, total=   1.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.233, total=   1.2s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.250, total=   1.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.257, total=   1.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.726, total=   1.7s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.737, total=   1.7s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.728, total=   1.8s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.705, total=   1.9s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.732, total=   1.8s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.648, total=   1.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.633, total=   1.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.659, total=   1.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.626, total=   1.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.639, total=   1.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.489, total=   0.9s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.501, total=   0.9s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.512, total=   0.9s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.537, total=   0.9s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.507, total=   0.9s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.362, total=   1.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.385, total=   1.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.383, total=   1.6s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.383, total=   1.4s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.377, total=   1.4s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.251, total=   1.2s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.259, total=   1.7s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.256, total=   1.2s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.258, total=   1.1s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.265, total=   1.1s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.781, total=   2.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.780, total=   2.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.786, total=   2.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.768, total=   2.1s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.786, total=   2.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.752, total=   1.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.724, total=   1.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.737, total=   1.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.749, total=   1.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.753, total=   1.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.641, total=   0.8s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.626, total=   0.8s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.657, total=   0.8s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.617, total=   0.8s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.641, total=   0.9s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.470, total=   0.9s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.496, total=   0.9s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.511, total=   1.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.502, total=   1.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.495, total=   1.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.388, total=   1.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.405, total=   1.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.387, total=   1.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.392, total=   1.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.366, total=   1.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.788, total=   2.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.783, total=   2.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.794, total=   2.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.767, total=   2.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.796, total=   2.1s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.770, total=   1.8s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.780, total=   1.8s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.801, total=   1.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.794, total=   1.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.810, total=   1.8s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.726, total=   1.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.706, total=   1.3s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.721, total=   1.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.684, total=   1.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.712, total=   1.3s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.592, total=   1.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.610, total=   1.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.610, total=   1.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.587, total=   1.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.631, total=   1.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.431, total=   1.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.476, total=   1.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.463, total=   1.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.486, total=   1.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.497, total=   1.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.786, total=   2.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.786, total=   2.0s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.794, total=   2.1s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.765, total=   2.1s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.796, total=   2.0s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.791, total=   3.1s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.822, total=   3.3s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.829, total=   4.6s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.809, total=   3.6s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.814, total=   3.2s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.741, total=   3.7s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.773, total=   4.2s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.793, total=   3.6s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.770, total=   3.6s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.752, total=   4.0s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.680, total=   2.1s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.679, total=   2.3s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.669, total=   2.2s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.657, total=   2.3s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.690, total=   2.1s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.591, total=   1.3s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.602, total=   1.3s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.582, total=   1.3s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.608, total=   1.3s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.613, total=   1.3s
# [Parallel(n_jobs=1)]: Done 125 out of 125 | elapsed:  3.2min finished
# Confusion Matrix:
# [[152   1   0   0   0   0]
#  [  0 164  15   1   0   0]
#  [  4  19 111  29   6   0]
#  [  4   7  40 103  15   7]
#  [  2   2   7  15 161   3]
#  [  0   0   0   2  10 142]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#          3.0       0.94      0.99      0.97       153
#          4.0       0.85      0.91      0.88       180
#          5.0       0.64      0.66      0.65       169
#          6.0       0.69      0.59      0.63       176
#          7.0       0.84      0.85      0.84       190
#          8.0       0.93      0.92      0.93       154
#
#     accuracy                           0.82      1022
#    macro avg       0.81      0.82      0.82      1022
# weighted avg       0.81      0.82      0.81      1022

# %% [markdown]
# Our grid search has increased the accuracy we were able to achieve from 37% to 82%.
#
# #### 3.2.5: XGBoost

# %%
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
xgbpreds = xgb.predict(X_test)

print("Confusion Matrix: ")
print(confusion_matrix(y_test,xgbpreds))
print("-" * 50)
print("Classification Report: ")
print(classification_report(y_test,xgbpreds))
# Out:
# Confusion Matrix:
# [[151   2   0   0   0   0]
#  [  4 146  26   3   1   0]
#  [  5  13 111  27  11   2]
#  [  7   6  47  65  42   9]
#  [  1   1   5  20 144  19]
#  [  0   0   0   1   3 150]]
# --------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#          3.0       0.90      0.99      0.94       153
#          4.0       0.87      0.81      0.84       180
#          5.0       0.59      0.66      0.62       169
#          6.0       0.56      0.37      0.45       176
#          7.0       0.72      0.76      0.74       190
#          8.0       0.83      0.97      0.90       154
#
#     accuracy                           0.75      1022
#    macro avg       0.74      0.76      0.75      1022
# weighted avg       0.74      0.75      0.74      1022

# %% [markdown]
# Our XGBoost model achieved a 75% accuracy.
